# %%
#Import dependencies
import requests
from bs4 import BeautifulSoup
import random
import pandas as pd
import logging
from tqdm import tqdm
import time

# %%
title = "Software Developer"  
location = "Linköping"

# %%
from collections import defaultdict
programming_languages = pd.read_csv('./skills.csv')['skills'].to_list()
programming_languages = set(programming_languages)

users_of_languages = defaultdict(int)
for l in programming_languages:
    users_of_languages[l] = 0

# %%
job_list = []

# %%
for start in tqdm(range(0, 100, 25)):
    list_url = f"https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords={title}&location={location}&start={start}"

    response = requests.get(list_url)

    list_data = response.text
    list_soup = BeautifulSoup(list_data, "html.parser")
    page_jobs = list_soup.find_all("li")
        
    id_list = []

    for job in page_jobs:
        base_card_div = job.find("div", {"class": "base-card"})
        job_id = base_card_div.get("data-entity-urn").split(":")[3]
        id_list.append(job_id)
    
    for job_id in id_list:
        job_url = f"https://www.linkedin.com/jobs-guest/jobs/api/jobPosting/{job_id}"
        
        job_response = requests.get(job_url)
        if job_response.status_code != 200:
            logging.warning(f"Failed to retrieve job posting {job_id}: Status code {job_response.status_code}")
            continue
        job_soup = BeautifulSoup(job_response.text, "html.parser")
        
        job_post = {}
        
        try:
            job_post["job_title"] = job_soup.find("h2", {"class":"top-card-layout__title font-sans text-lg papabear:text-xl font-bold leading-open text-color-text mb-0 topcard__title"}).text.strip()
        except:
            job_post["job_title"] = None
            
        try:
            job_post["company_name"] = job_soup.find("a", {"class": "topcard__org-name-link topcard__flavor--black-link"}).text.strip()
        except:
            job_post["company_name"] = None
            
        try:
            job_post["time_posted"] = job_soup.find("span", {"class": "posted-time-ago__text topcard__flavor--metadata"}).text.strip()
        except:
            job_post["time_posted"] = None
            
        try:
            job_post["num_applicants"] = job_soup.find("span", {"class": "num-applicants__caption topcard__flavor--metadata topcard__flavor--bullet"}).text.strip()
        except:
            job_post["num_applicants"] = None

        for lang in programming_languages:
            # description is in show-more-less-html__markup show-more-less-html__markup--clamp-after-5 relative overflow-hidden
            if f" {lang.lower()}" in job_soup.find("div", {"class": "show-more-less-html__markup show-more-less-html__markup--clamp-after-5 relative overflow-hidden"}).text.lower():  
                users_of_languages[lang] += 1 
        job_list.append(job_post)
        time.sleep(random.uniform(1, 5))
# Out:
#  50%|█████     | 2/4 [00:09<00:09,  4.63s/it]WARNING:root:Failed to retrieve job posting 4319834596: Status code 429
# WARNING:root:Failed to retrieve job posting 4081232113: Status code 429
# 100%|██████████| 4/4 [00:18<00:00,  4.62s/it]

# %%
# Create a pandas DataFrame using the list of job dictionaries 'job_list'
jobs_df = pd.DataFrame(job_list)
jobs_df
# Out:
#                                             job_title  \
# 0   Algoritmutveckling / Reglerteknik / Modellbase...
# 1                                  SOFTWARE DEVELOPER
# 2                                   Software Engineer
# 3                      System developer to Linköping!
# 4                                 Embedded-utvecklare
# 5                                 Fullstack Developer
# 6                               Testare inom mjukvara
# 7                                    C/C++-utvecklare
# 8        Software Developer, Backend - Sectra Medical
# 9                                 Embedded-utvecklare
# 10  Fullstack Utvecklare & Arkitekter till Product...
# 11                        Embedded Software Developer
# 12  Juniora utvecklare till nästa generations moln...
# 13      Systems Engineer, Staff - Qualcomm, Linkoping
# 14                        Senior Fullstack-utvecklare
# 15     Junior Mjukvaruutvecklare inom inbyggda system
# 16              "Follow The Sun" Tech Student Program
# 17                        Fullstackutvecklare C#/.NET
# 18                   AI Engineer - Autonomous systems
# 19                      Utvecklare C#/.Net Norrköping
# 20            FPGA-utvecklare – Sectra Communications
# 21           Software Developer | Linköping | Experis
# 22                          Machine Learning Engineer
# 23                      Data Engineer till Addovation
# 24                                 Mjukvaruutvecklare
# 25                 Summer Internship 2026 - Linköping
# 26                           Computer Vision Engineer
# 27  Software Engineer, Contributing to Scandinavia...
# 28  Systemutvecklare till B3 Connect Linköping - S...
# 29  Mjukvaruutvecklare - C++, Computer Vision, ML,...
# 30                Systems Engineer - Design Authority
# 31                            CAM Specialist - Eviden
# 32                                      Data Engineer
# 33                            Senior Systemutvecklare
# 34            Mjukvaruutvecklare inom systemlösningar
# 35  Master’s Thesis- Exploring AI for Software Tes...
# 36                                      Data Engineer
# 37                            Embedded Lead Developer
#
#                                      company_name   time_posted  \
# 0                                         Combine   2 weeks ago
# 1                                            Atos    2 days ago
# 2                                          Medius  2 months ago
# 3                                      TMC Sweden    6 days ago
# 4                                          Consid    1 year ago
# 5                                    Cambio Group    4 days ago
# 6                          Professional Galaxy AB  8 months ago
# 7                                         Deploja    2 days ago
# 8                                          Sectra   2 weeks ago
# 9                                          Consid    1 year ago
# 10                                           Saab   2 weeks ago
# 11                                     Softube AB          None
# 12                                   Framtiden AB    5 days ago
# 13                                       Qualcomm    6 days ago
# 14                         Rasulson Consulting AB   4 weeks ago
# 15                                         Sectra    1 week ago
# 16                                         Sectra    1 week ago
# 17                                    Nexer Group    2 days ago
# 18                                           Saab          None
# 19                                         Castra    1 week ago
# 20                                         Sectra   2 weeks ago
# 21                                 Experis Sweden    1 week ago
# 22                                      RemaSawco   2 weeks ago
# 23                                     Addovation   1 month ago
# 24                          Capgemini Engineering          None
# 25                        Opera News South Africa    1 week ago
# 26                                           Saab     1 day ago
# 27                                         Sectra   2 weeks ago
# 28                            B3 Consulting Group   2 weeks ago
# 29                         Professional Galaxy AB   1 month ago
# 30                                           Saab   2 weeks ago
# 31                                         Eviden    5 days ago
# 32                                      RemaSawco   2 weeks ago
# 33                                        Deploja   1 month ago
# 34              Syntronic - A Global Design House  7 months ago
# 35                                   Cambio Group          None
# 36                                  WSP i Sverige          None
# 37  Toyota Material Handling Manufacturing Sweden     1 day ago
#
#     num_applicants
# 0             None
# 1   136 applicants
# 2             None
# 3    26 applicants
# 4             None
# 5    37 applicants
# 6    39 applicants
# 7             None
# 8   192 applicants
# 9             None
# 10            None
# 11            None
# 12            None
# 13  101 applicants
# 14            None
# 15            None
# 16            None
# 17            None
# 18            None
# 19            None
# 20   49 applicants
# 21            None
# 22   42 applicants
# 23            None
# 24            None
# 25            None
# 26            None
# 27   39 applicants
# 28   77 applicants
# 29            None
# 30            None
# 31   35 applicants
# 32            None
# 33            None
# 34            None
# 35            None
# 36   52 applicants
# 37            None

# %%
lang_usage = pd.DataFrame.from_dict(users_of_languages, orient='index', columns=['Number of Job Postings']).reset_index().rename(columns={'index': 'Programming Language'})
lang_usage.drop(lang_usage[lang_usage['Number of Job Postings'] == 0].index, inplace=True)
lang_usage = lang_usage.sort_values(by='Number of Job Postings', ascending=False)
lang_usage = lang_usage.reset_index(drop=True)
lang_usage
# Out:
#    Programming Language  Number of Job Postings
# 0                     C                      36
# 1                Python                      15
# 2                 Linux                      12
# 3                    C#                      12
# 4                   C++                      10
# 5                 Azure                      10
# 6                 C/C++                       8
# 7                   SQL                       7
# 8                   Git                       6
# 9                  Java                       5
# 10                 .NET                       5
# 11           Kubernetes                       5
# 12                  Ada                       4
# 13                Scala                       4
# 14                Agile                       4
# 15                React                       4
# 16               DevOps                       4
# 17               Kanban                       3
# 18           TypeScript                       3
# 19               Docker                       3
# 20                  AWS                       2
# 21                 Rust                       2
# 22                CI/CD                       2
# 23           JavaScript                       2
# 24               MATLAB                       2
# 25                Scrum                       1
# 26          Spring Boot                       1
# 27           PostgreSQL                       1
